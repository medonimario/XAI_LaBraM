# %%
import mne
import numpy as np
import matplotlib.pyplot as plt

# %%
epochs_path = "/Volumes/T9/FG_Data_For_Students/PreprocessedEEGData/Train"
subject = "301A_FG_preprocessed-epo.fif"
epochs = mne.read_epochs(f"{epochs_path}/{subject}", preload=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 epochs_path = "/Volumes/T9/FG_Data_For_Students/PreprocessedEEGData/Train"
#       2 subject = "301A_FG_preprocessed-epo.fif"
# ----> 3 epochs = mne.read_epochs(f"{epochs_path}/{subject}", preload=True)
#
# File <decorator-gen-232>:12, in read_epochs(fname, proj, preload, verbose)
#
# File ~/miniconda3/envs/mirror/lib/python3.13/site-packages/mne/epochs.py:4231, in read_epochs(fname, proj, preload, verbose)
#    4213 @verbose
#    4214 def read_epochs(fname, proj=True, preload=True, verbose=None) -> "EpochsFIF":
#    4215     """Read epochs from a fif file.
#    4216
#    4217     Parameters
#    (...)   4229         The epochs.
#    4230     """
# -> 4231     return EpochsFIF(fname, proj, preload, verbose)
#
# File <decorator-gen-233>:12, in __init__(self, fname, proj, preload, verbose)
#
# ...

# %%
epochs.info
# Out:
# <Info | 12 non-empty values
#  bads: []
#  ch_names: Fp1, AF7, AF3, F1, F3, F5, F7, FT7, FC5, FC3, FC1, C1, C3, C5, ...
#  chs: 64 EEG
#  custom_ref_applied: True
#  dig: 67 items (3 Cardinal, 64 EEG)
#  file_id: 4 items (dict)
#  highpass: 1.0 Hz
#  lowpass: 40.0 Hz
#  meas_date: 2023-10-11 14:54:47 UTC
#  meas_id: 4 items (dict)
#  nchan: 64
#  projs: []
#  sfreq: 500.0 Hz
#  subject_info: <subject_info | >
# >

# %%
epochs.event_id
# Out:
# {'T1P': 301,
#  'T1Pn': 302,
#  'T3P': 303,
#  'T3Pn': 304,
#  'T12P': 305,
#  'T12Pn': 306,
#  'T13P': 307,
#  'T13Pn': 308,
#  'T23P': 309,
#  'T23Pn': 310}

# %%
for key in epochs.event_id.keys():
    print(f"{key}: {len(epochs[key])}")
# Out:
# T1P: 30
# T1Pn: 30
# T3P: 30
# T3Pn: 30
# T12P: 30
# T12Pn: 30
# T13P: 30
# T13Pn: 30
# T23P: 30
# T23Pn: 30

# %%
epochs.ch_names
# Out:
# ['Fp1',
#  'AF7',
#  'AF3',
#  'F1',
#  'F3',
#  'F5',
#  'F7',
#  'FT7',
#  'FC5',
#  'FC3',
#  'FC1',
#  'C1',
#  'C3',
#  'C5',
#  'T7',
#  'TP7',
#  'CP5',
#  'CP3',
#  'CP1',
#  'P1',
#  'P3',
#  'P5',
#  'P7',
#  'P9',
#  'PO7',
#  'PO3',
#  'O1',
#  'Iz',
#  'Oz',
#  'POz',
#  'Pz',
#  'CPz',
#  'Fpz',
#  'Fp2',
#  'AF8',
#  'AF4',
#  'AFz',
#  'Fz',
#  'F2',
#  'F4',
#  'F6',
#  'F8',
#  'FT8',
#  'FC6',
#  'FC4',
#  'FC2',
#  'FCz',
#  'Cz',
#  'C2',
#  'C4',
#  'C6',
#  'T8',
#  'TP8',
#  'CP6',
#  'CP4',
#  'CP2',
#  'P2',
#  'P4',
#  'P6',
#  'P8',
#  'P10',
#  'PO8',
#  'PO4',
#  'O2']

# %%
epochs.get_data().shape
# Out:
# (300, 64, 3000)

# %% [markdown]
# ## Mirror

# %%
epochs_path = "/Users/s204684/Work/Special Course 2/Mirror_LEiDA/data/raw_eeg/raw_all/PPT1/"
subject = "s_101_Coordination.set"
epochs = mne.read_epochs_eeglab(f"{epochs_path}/{subject}")
epochs.info
# Out:
# Extracting parameters from /Users/s204684/Work/Special Course 2/Mirror_LEiDA/data/raw_eeg/raw_all/PPT1/s_101_Coordination.set...
# Not setting metadata
# 87 matching events found
# No baseline correction applied
# 0 projection items activated
# Ready.
# /var/folders/h6/wwzpvb4141g4m6j_2c1k19gr0000gp/T/ipykernel_4132/3521135038.py:3: RuntimeWarning: At least one epoch has multiple events. Only the latency of the first event will be retained.
#   epochs = mne.read_epochs_eeglab(f"{epochs_path}/{subject}")
# /var/folders/h6/wwzpvb4141g4m6j_2c1k19gr0000gp/T/ipykernel_4132/3521135038.py:3: RuntimeWarning: Data file name in EEG.data (s_01_Coordination_AverageReref.fdt) is incorrect, the file name must have changed on disk, using the correct file name (s_101_Coordination.fdt).
#   epochs = mne.read_epochs_eeglab(f"{epochs_path}/{subject}")
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, AF7, AF3, F1, F3, F5, F7, FT7, FC5, FC3, FC1, C1, C3, C5, ...
#  chs: 64 EEG
# ...

# %%
epochs.ch_names
# Out:
# ['Fp1',
#  'AF7',
#  'AF3',
#  'F1',
#  'F3',
#  'F5',
#  'F7',
#  'FT7',
#  'FC5',
#  'FC3',
#  'FC1',
#  'C1',
#  'C3',
#  'C5',
#  'T7',
#  'TP7',
#  'CP5',
#  'CP3',
#  'CP1',
#  'P1',
#  'P3',
#  'P5',
#  'P7',
#  'P9',
#  'PO7',
#  'PO3',
#  'O1',
#  'Iz',
#  'Oz',
#  'POz',
#  'Pz',
#  'CPz',
#  'Fpz',
#  'Fp2',
#  'AF8',
#  'AF4',
#  'AFz',
#  'Fz',
#  'F2',
#  'F4',
#  'F6',
#  'F8',
#  'FT8',
#  'FC6',
#  'FC4',
#  'FC2',
#  'FCz',
#  'Cz',
#  'C2',
#  'C4',
#  'C6',
#  'T8',
#  'TP8',
#  'CP6',
#  'CP4',
#  'CP2',
#  'P2',
#  'P4',
#  'P6',
#  'P8',
#  'P10',
#  'PO8',
#  'PO4',
#  'O2']

# %%
epochs.get_data().shape
# Out:
# (87, 64, 1536)

# %%
for key in epochs.event_id.keys():
    print(f"{key}: {len(epochs[key])}")
# Out:
# 154/134/134: 87
# 134/114/154/134: 40
# 114/154/134/134: 40
# 134/154/134: 87
